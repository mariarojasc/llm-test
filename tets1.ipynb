# %%
# %pip install streamlit
# %pip install streamlit-chat
# %pip install langchain
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: streamlit in ./.conda/lib/python3.8/site-packages (1.28.1)
# Requirement already satisfied: altair<6,>=4.0 in ./.conda/lib/python3.8/site-packages (from streamlit) (5.1.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in ./.conda/lib/python3.8/site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in ./.conda/lib/python3.8/site-packages (from streamlit) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in ./.conda/lib/python3.8/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in ./.conda/lib/python3.8/site-packages (from streamlit) (6.8.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in ./.conda/lib/python3.8/site-packages (from streamlit) (1.24.4)
# Requirement already satisfied: packaging<24,>=16.8 in ./.conda/lib/python3.8/site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in ./.conda/lib/python3.8/site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in ./.conda/lib/python3.8/site-packages (from streamlit) (10.1.0)
# Requirement already satisfied: protobuf<5,>=3.20 in ./.conda/lib/python3.8/site-packages (from streamlit) (4.25.0)
# Requirement already satisfied: pyarrow>=6.0 in ./.conda/lib/python3.8/site-packages (from streamlit) (14.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in ./.conda/lib/python3.8/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in ./.conda/lib/python3.8/site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in ./.conda/lib/python3.8/site-packages (from streamlit) (13.6.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in ./.conda/lib/python3.8/site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in ./.conda/lib/python3.8/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in ./.conda/lib/python3.8/site-packages (from streamlit) (4.8.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in ./.conda/lib/python3.8/site-packages (from streamlit) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in ./.conda/lib/python3.8/site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in ./.conda/lib/python3.8/site-packages (from streamlit) (3.1.40)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in ./.conda/lib/python3.8/site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in ./.conda/lib/python3.8/site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: jinja2 in ./.conda/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in ./.conda/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in ./.conda/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.conda/lib/python3.8/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in ./.conda/lib/python3.8/site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in ./.conda/lib/python3.8/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.conda/lib/python3.8/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in ./.conda/lib/python3.8/site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.conda/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.conda/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.conda/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.conda/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Requirement already satisfied: backports.zoneinfo in ./.conda/lib/python3.8/site-packages (from tzlocal<6,>=1.1->streamlit) (0.2.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.conda/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/lib/python3.8/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in ./.conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in ./.conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (6.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in ./.conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in ./.conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: mdurl~=0.1 in ./.conda/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: streamlit-chat in ./.conda/lib/python3.8/site-packages (0.1.1)
# Requirement already satisfied: streamlit>=0.63 in ./.conda/lib/python3.8/site-packages (from streamlit-chat) (1.28.1)
# Requirement already satisfied: altair<6,>=4.0 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (5.1.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (8.1.7)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (6.8.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (1.24.4)
# Requirement already satisfied: packaging<24,>=16.8 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (10.1.0)
# Requirement already satisfied: protobuf<5,>=3.20 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (4.25.0)
# Requirement already satisfied: pyarrow>=6.0 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (14.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (13.6.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (4.8.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (3.1.40)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in ./.conda/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-chat) (6.3.3)
# Requirement already satisfied: jinja2 in ./.conda/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in ./.conda/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (4.19.2)
# Requirement already satisfied: toolz in ./.conda/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.conda/lib/python3.8/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.63->streamlit-chat) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in ./.conda/lib/python3.8/site-packages (from importlib-metadata<7,>=1.4->streamlit>=0.63->streamlit-chat) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in ./.conda/lib/python3.8/site-packages (from pandas<3,>=1.3.0->streamlit>=0.63->streamlit-chat) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.conda/lib/python3.8/site-packages (from pandas<3,>=1.3.0->streamlit>=0.63->streamlit-chat) (2023.3)
# Requirement already satisfied: six>=1.5 in ./.conda/lib/python3.8/site-packages (from python-dateutil<3,>=2.7.3->streamlit>=0.63->streamlit-chat) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.conda/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-chat) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.conda/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-chat) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-chat) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-chat) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.conda/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit>=0.63->streamlit-chat) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.conda/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit>=0.63->streamlit-chat) (2.16.1)
# Requirement already satisfied: backports.zoneinfo in ./.conda/lib/python3.8/site-packages (from tzlocal<6,>=1.1->streamlit>=0.63->streamlit-chat) (0.2.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.conda/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.63->streamlit-chat) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/lib/python3.8/site-packages (from jinja2->altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in ./.conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (23.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in ./.conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (6.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (2023.7.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in ./.conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in ./.conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (0.12.0)
# Requirement already satisfied: mdurl~=0.1 in ./.conda/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=0.63->streamlit-chat) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain in ./.conda/lib/python3.8/site-packages (0.0.330)
# Requirement already satisfied: PyYAML>=5.3 in ./.conda/lib/python3.8/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./.conda/lib/python3.8/site-packages (from langchain) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./.conda/lib/python3.8/site-packages (from langchain) (3.8.6)
# Requirement already satisfied: anyio<4.0 in ./.conda/lib/python3.8/site-packages (from langchain) (3.7.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in ./.conda/lib/python3.8/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./.conda/lib/python3.8/site-packages (from langchain) (0.6.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.conda/lib/python3.8/site-packages (from langchain) (1.33)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.52 in ./.conda/lib/python3.8/site-packages (from langchain) (0.0.57)
# Requirement already satisfied: numpy<2,>=1 in ./.conda/lib/python3.8/site-packages (from langchain) (1.24.4)
# Requirement already satisfied: pydantic<3,>=1 in ./.conda/lib/python3.8/site-packages (from langchain) (2.4.2)
# Requirement already satisfied: requests<3,>=2 in ./.conda/lib/python3.8/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./.conda/lib/python3.8/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: attrs>=17.3.0 in ./.conda/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in ./.conda/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.conda/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.conda/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.conda/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.conda/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: idna>=2.8 in ./.conda/lib/python3.8/site-packages (from anyio<4.0->langchain) (3.4)
# Requirement already satisfied: sniffio>=1.1 in ./.conda/lib/python3.8/site-packages (from anyio<4.0->langchain) (1.3.0)
# Requirement already satisfied: exceptiongroup in ./.conda/lib/python3.8/site-packages (from anyio<4.0->langchain) (1.1.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.conda/lib/python3.8/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./.conda/lib/python3.8/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./.conda/lib/python3.8/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.conda/lib/python3.8/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in ./.conda/lib/python3.8/site-packages (from pydantic<3,>=1->langchain) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./.conda/lib/python3.8/site-packages (from pydantic<3,>=1->langchain) (4.8.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/lib/python3.8/site-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/lib/python3.8/site-packages (from requests<3,>=2->langchain) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in ./.conda/lib/python3.8/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: packaging>=17.0 in ./.conda/lib/python3.8/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain) (23.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.conda/lib/python3.8/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting pypdf (from -r requirements.txt (line 1))
#   Using cached pypdf-3.17.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: langchain in ./.conda/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (0.0.330)
# Collecting torch (from -r requirements.txt (line 3))
#   Using cached torch-2.1.0-cp38-none-macosx_10_9_x86_64.whl.metadata (24 kB)
# Collecting accelerate (from -r requirements.txt (line 4))
#   Using cached accelerate-0.24.1-py3-none-any.whl.metadata (18 kB)
# Collecting bitsandbytes (from -r requirements.txt (line 5))
#   Using cached bitsandbytes-0.41.1-py3-none-any.whl.metadata (9.8 kB)
# Collecting transformers (from -r requirements.txt (line 6))
#   Using cached transformers-4.35.0-py3-none-any.whl.metadata (123 kB)
# Collecting sentence_transformers (from -r requirements.txt (line 7))
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# Collecting faiss-cpu (from -r requirements.txt (line 8))
#   Using cached faiss_cpu-1.7.4-cp38-cp38-macosx_10_9_x86_64.whl (6.5 MB)
# Collecting ctransformers (from -r requirements.txt (line 9))
#   Using cached ctransformers-0.2.27-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: typing_extensions>=3.7.4.3 in ./.conda/lib/python3.8/site-packages (from pypdf->-r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: PyYAML>=5.3 in ./.conda/lib/python3.8/site-packages (from langchain->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./.conda/lib/python3.8/site-packages (from langchain->-r requirements.txt (line 2)) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./.conda/lib/python3.8/site-packages (from langchain->-r requirements.txt (line 2)) (3.8.6)
# Requirement already satisfied: anyio<4.0 in ./.conda/lib/python3.8/site-packages (from langchain->-r requirements.txt (line 2)) (3.7.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in ./.conda/lib/python3.8/site-packages (from langchain->-r requirements.txt (line 2)) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./.conda/lib/python3.8/site-packages (from langchain->-r requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.conda/lib/python3.8/site-packages (from langchain->-r requirements.txt (line 2)) (1.33)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.52 in ./.conda/lib/python3.8/site-packages (from langchain->-r requirements.txt (line 2)) (0.0.57)
# Requirement already satisfied: numpy<2,>=1 in ./.conda/lib/python3.8/site-packages (from langchain->-r requirements.txt (line 2)) (1.24.4)
# Requirement already satisfied: pydantic<3,>=1 in ./.conda/lib/python3.8/site-packages (from langchain->-r requirements.txt (line 2)) (2.4.2)
# Requirement already satisfied: requests<3,>=2 in ./.conda/lib/python3.8/site-packages (from langchain->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./.conda/lib/python3.8/site-packages (from langchain->-r requirements.txt (line 2)) (8.2.3)
# Collecting filelock (from torch->-r requirements.txt (line 3))
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting sympy (from torch->-r requirements.txt (line 3))
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx (from torch->-r requirements.txt (line 3))
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Requirement already satisfied: jinja2 in ./.conda/lib/python3.8/site-packages (from torch->-r requirements.txt (line 3)) (3.1.2)
# Collecting fsspec (from torch->-r requirements.txt (line 3))
#   Using cached fsspec-2023.10.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: packaging>=20.0 in ./.conda/lib/python3.8/site-packages (from accelerate->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: psutil in ./.conda/lib/python3.8/site-packages (from accelerate->-r requirements.txt (line 4)) (5.9.5)
# Collecting huggingface-hub (from accelerate->-r requirements.txt (line 4))
#   Using cached huggingface_hub-0.18.0-py3-none-any.whl.metadata (13 kB)
# Collecting regex!=2019.12.17 (from transformers->-r requirements.txt (line 6))
#   Using cached regex-2023.10.3-cp38-cp38-macosx_10_9_x86_64.whl.metadata (40 kB)
# Collecting tokenizers<0.15,>=0.14 (from transformers->-r requirements.txt (line 6))
#   Using cached tokenizers-0.14.1-cp38-cp38-macosx_10_7_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.3.1 (from transformers->-r requirements.txt (line 6))
#   Using cached safetensors-0.4.0-cp38-cp38-macosx_10_7_x86_64.whl.metadata (3.8 kB)
# Collecting tqdm>=4.27 (from transformers->-r requirements.txt (line 6))
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Collecting torchvision (from sentence_transformers->-r requirements.txt (line 7))
#   Using cached torchvision-0.16.0-cp38-cp38-macosx_10_13_x86_64.whl.metadata (6.6 kB)
# Collecting scikit-learn (from sentence_transformers->-r requirements.txt (line 7))
#   Using cached scikit_learn-1.3.2-cp38-cp38-macosx_10_9_x86_64.whl.metadata (11 kB)
# Collecting scipy (from sentence_transformers->-r requirements.txt (line 7))
#   Using cached scipy-1.10.1-cp38-cp38-macosx_10_9_x86_64.whl (35.0 MB)
# Collecting nltk (from sentence_transformers->-r requirements.txt (line 7))
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting sentencepiece (from sentence_transformers->-r requirements.txt (line 7))
#   Using cached sentencepiece-0.1.99-cp38-cp38-macosx_10_9_x86_64.whl (1.2 MB)
# Collecting py-cpuinfo<10.0.0,>=9.0.0 (from ctransformers->-r requirements.txt (line 9))
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: attrs>=17.3.0 in ./.conda/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in ./.conda/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.conda/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.conda/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.conda/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.conda/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: idna>=2.8 in ./.conda/lib/python3.8/site-packages (from anyio<4.0->langchain->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: sniffio>=1.1 in ./.conda/lib/python3.8/site-packages (from anyio<4.0->langchain->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: exceptiongroup in ./.conda/lib/python3.8/site-packages (from anyio<4.0->langchain->-r requirements.txt (line 2)) (1.1.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.conda/lib/python3.8/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain->-r requirements.txt (line 2)) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./.conda/lib/python3.8/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain->-r requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./.conda/lib/python3.8/site-packages (from jsonpatch<2.0,>=1.33->langchain->-r requirements.txt (line 2)) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.conda/lib/python3.8/site-packages (from pydantic<3,>=1->langchain->-r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in ./.conda/lib/python3.8/site-packages (from pydantic<3,>=1->langchain->-r requirements.txt (line 2)) (2.10.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/lib/python3.8/site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 2)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/lib/python3.8/site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in ./.conda/lib/python3.8/site-packages (from SQLAlchemy<3,>=1.4->langchain->-r requirements.txt (line 2)) (3.0.1)
# Collecting huggingface-hub (from accelerate->-r requirements.txt (line 4))
#   Using cached huggingface_hub-0.17.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/lib/python3.8/site-packages (from jinja2->torch->-r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: click in ./.conda/lib/python3.8/site-packages (from nltk->sentence_transformers->-r requirements.txt (line 7)) (8.1.7)
# Collecting joblib (from nltk->sentence_transformers->-r requirements.txt (line 7))
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->sentence_transformers->-r requirements.txt (line 7))
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Collecting mpmath>=0.19 (from sympy->torch->-r requirements.txt (line 3))
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.conda/lib/python3.8/site-packages (from torchvision->sentence_transformers->-r requirements.txt (line 7)) (10.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.conda/lib/python3.8/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain->-r requirements.txt (line 2)) (1.0.0)
# Using cached pypdf-3.17.0-py3-none-any.whl (277 kB)
# Using cached torch-2.1.0-cp38-none-macosx_10_9_x86_64.whl (146.7 MB)
# Using cached accelerate-0.24.1-py3-none-any.whl (261 kB)
# Using cached bitsandbytes-0.41.1-py3-none-any.whl (92.6 MB)
# Using cached transformers-4.35.0-py3-none-any.whl (7.9 MB)
# Using cached ctransformers-0.2.27-py3-none-any.whl (9.9 MB)
# Using cached fsspec-2023.10.0-py3-none-any.whl (166 kB)
# Using cached regex-2023.10.3-cp38-cp38-macosx_10_9_x86_64.whl (296 kB)
# Using cached safetensors-0.4.0-cp38-cp38-macosx_10_7_x86_64.whl (439 kB)
# Using cached tokenizers-0.14.1-cp38-cp38-macosx_10_7_x86_64.whl (2.5 MB)
# Using cached huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached scikit_learn-1.3.2-cp38-cp38-macosx_10_9_x86_64.whl (10.1 MB)
# Using cached torchvision-0.16.0-cp38-cp38-macosx_10_13_x86_64.whl (1.7 MB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: sentencepiece, py-cpuinfo, mpmath, faiss-cpu, bitsandbytes, tqdm, threadpoolctl, sympy, scipy, safetensors, regex, pypdf, networkx, joblib, fsspec, filelock, torch, scikit-learn, nltk, huggingface-hub, torchvision, tokenizers, ctransformers, accelerate, transformers, sentence_transformers

# %%
# Import necessary libraries
import streamlit as st
from streamlit_chat import message
import tempfile
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.llms import CTransformers
from langchain.chains import ConversationalRetrievalChain

# Define the path for generated embeddings
DB_FAISS_PATH = 'vectorstore/db_faiss'

# %%
# Load the model of choice
def load_llm():
    llm = CTransformers(
        model="llama-2-7b-chat.ggmlv3.q8_0.bin",
        model_type="llama",
        max_new_tokens=512,
        temperature=0.5
    )
    return llm

# %%
# Set the title for the Streamlit app
st.title("Llama2 Chat PDF - 🦜🦙")

# Create a file uploader in the sidebar
uploaded_file = st.sidebar.file_uploader("Upload File", type="csv")

# %%
# Handle file upload
if uploaded_file:
    with tempfile.NamedTemporaryFile(delete=False) as tmp_file:
        tmp_file.write(uploaded_file.getvalue())
        tmp_file_path = tmp_file.name

    # Load CSV data using CSVLoader
    loader = CSVLoader(file_path=tmp_file_path, encoding="utf-8", csv_args={'delimiter': ','})
    data = loader.load()

    # Create embeddings using Sentence Transformers
    embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2', model_kwargs={'device': 'cpu'})

    # Create a FAISS vector store and save embeddings
    db = FAISS.from_documents(data, embeddings)
    db.save_local(DB_FAISS_PATH)

    # Load the language model
    llm = load_llm()

    # Create a conversational chain
    chain = ConversationalRetrievalChain.from_llm(llm=llm, retriever=db.as_retriever())

    # Function for conversational chat
    def conversational_chat(query):
        result = chain({"question": query, "chat_history": st.session_state['history']})
        st.session_state['history'].append((query, result["answer"]))
        return result["answer"]

    # Initialize chat history
    if 'history' not in st.session_state:
        st.session_state['history'] = []

    # Initialize messages
    if 'generated' not in st.session_state:
        st.session_state['generated'] = ["Hello ! Ask me(LLAMA2) about " + uploaded_file.name + " 🤗"]

    if 'past' not in st.session_state:
        st.session_state['past'] = ["Hey ! 👋"]

    # Create containers for chat history and user input
    response_container = st.container()
    container = st.container()

    # User input form
    with container:
        with st.form(key='my_form', clear_on_submit=True):
            user_input = st.text_input("Query:", placeholder="Talk to csv data 👉 (:", key='input')
            submit_button = st.form_submit_button(label='Send')

        if submit_button and user_input:
            output = conversational_chat(user_input)
            st.session_state['past'].append(user_input)
            st.session_state['generated'].append(output)

    # Display chat history
    if st.session_state['generated']:
        with response_container:
            for i in range(len(st.session_state['generated'])):
                message(st.session_state["past"][i], is_user=True, key=str(i) + '_user', avatar_style="big-smile")
                message(st.session_state["generated"][i], key=str(i), avatar_style="thumbs")
